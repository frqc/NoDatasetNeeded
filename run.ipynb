# %%
# !git clone https://github.com/frqc/NoDatasetNeeded.git
# %cd /content/NoDatasetNeeded/
# !git checkout  frustum_pointnets
# %cd frustum_pointnets/
# Out:
# Cloning into 'NoDatasetNeeded'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 13 (delta 0), reused 13 (delta 0), pack-reused 0
# Unpacking objects: 100% (13/13), done.
# /content/NoDatasetNeeded
# Branch 'frustum_pointnets' set up to track remote branch 'frustum_pointnets' from 'origin'.
# Switched to a new branch 'frustum_pointnets'
# /content/NoDatasetNeeded/frustum_pointnets

# %%
# !mkdir /opt/data
# !wget https://teamproject-data.s3.amazonaws.com/frustum_kitti.pickle -P /opt/data
# Out:
# --2021-04-05 23:59:35--  https://teamproject-data.s3.amazonaws.com/frustum_kitti.pickle
# Resolving teamproject-data.s3.amazonaws.com (teamproject-data.s3.amazonaws.com)... 52.216.106.116
# Connecting to teamproject-data.s3.amazonaws.com (teamproject-data.s3.amazonaws.com)|52.216.106.116|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 229416801 (219M) [application/x-www-form-urlencoded]
# Saving to: ‘/opt/data/frustum_kitti.pickle’
#
# frustum_kitti.pickl 100%[===================>] 218.79M  47.1MB/s    in 5.2s
#
# 2021-04-05 23:59:40 (42.5 MB/s) - ‘/opt/data/frustum_kitti.pickle’ saved [229416801/229416801]

# %%
import frustum_pointnet
import main
import model_util
import train
import data_provider

# %%
# !python3 train.py
# Out:
# **** EPOCH 001 ****
# Epoch 1/100:
# 100% 132/132 [00:46<00:00,  2.82it/s]
# Correct: 0.5414945429021661
# **** EPOCH 002 ****
# Epoch 2/100:
# 100% 132/132 [00:47<00:00,  2.75it/s]
# Correct: 0.5624849724047112
# **** EPOCH 003 ****
# Epoch 3/100:
# 100% 132/132 [00:46<00:00,  2.81it/s]
# Correct: 0.5282213615648674
# **** EPOCH 004 ****
# Epoch 4/100:
# 100% 132/132 [00:43<00:00,  3.02it/s]
# Correct: 0.5565017931389086
# **** EPOCH 005 ****
# Epoch 5/100:
# 100% 132/132 [00:44<00:00,  2.94it/s]
# Correct: 0.5616779905377012
# **** EPOCH 006 ****
# Epoch 6/100:
# 100% 132/132 [00:47<00:00,  2.78it/s]
# Correct: 0.5697562477805398
# **** EPOCH 007 ****
# Epoch 7/100:
# 100% 132/132 [00:48<00:00,  2.74it/s]
# Correct: 0.5659779635342684
# **** EPOCH 008 ****
# Epoch 8/100:
# 100% 132/132 [00:45<00:00,  2.93it/s]
# Correct: 0.5765512639825995
# **** EPOCH 009 ****
# Epoch 9/100:
# 100% 132/132 [00:44<00:00,  2.98it/s]
# Correct: 0.5770309910629735
# **** EPOCH 010 ****
# ...
